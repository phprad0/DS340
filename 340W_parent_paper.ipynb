# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-bright')

# %%
rating = pd.read_csv('ratings.csv')
rating.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510

# %%
movie_names = pd.read_csv('movies.csv') 
movie_names.head()
# Out:
#    movieId  ...                                       genres
# 0        1  ...  Adventure|Animation|Children|Comedy|Fantasy
# 1        2  ...                   Adventure|Children|Fantasy
# 2        3  ...                               Comedy|Romance
# 3        4  ...                         Comedy|Drama|Romance
# 4        5  ...                                       Comedy
#
# [5 rows x 3 columns]

# %%
movie_data = pd.merge(rating, movie_names, on='movieId')
movie_data.head()
# Out:
#    userId  movieId  ...                title                       genres
# 0       1      296  ...  Pulp Fiction (1994)  Comedy|Crime|Drama|Thriller
# 1       3      296  ...  Pulp Fiction (1994)  Comedy|Crime|Drama|Thriller
# 2       4      296  ...  Pulp Fiction (1994)  Comedy|Crime|Drama|Thriller
# 3       5      296  ...  Pulp Fiction (1994)  Comedy|Crime|Drama|Thriller
# 4       7      296  ...  Pulp Fiction (1994)  Comedy|Crime|Drama|Thriller
#
# [5 rows x 6 columns]

# %%
Trend=pd.DataFrame(movie_data.groupby ('title') ['rating'].mean ())
Trend ['total number of ratings'] = pd.DataFrame(movie_data.groupby ('title') ['rating'].count ())
Trend.head()
# Out:
#                                          rating  total number of ratings
# title
# "Great Performances" Cats (1998)          4.000                        5
# $5 a Day (2008)                           3.750                        2
# $9.99 (2008)                              2.500                        1
# '71 (2014)                                2.375                        4
# 'Hellboy': The Seeds of Creation (2004)   3.250                        2

# %%
plt.Figure(figsize = (10, 4))
As=plt.barh (Trend['rating'].round(), Trend['total number of ratings'],color ='b')
plt.show ()

# %%
plt.Figure(figsize=(10,4))
As=plt.subplot()
As.bar(Trend.head(25).index, Trend['total number of ratings'].head(25), color='b')
As.set_xticklabels(Trend.index, rotation=40, fontsize='12',horizontalalignment="right")
As.set_title ("Total Number of reviews for each movie")
plt.show ()

# %%
movie_data.groupby('title')['rating'].mean().sort_values(ascending=False).head(50)
# Out:
# title
# Mountain (2017)                                                                              5.0
# Damnation Alley (1977)                                                                       5.0
# Reach Me (2014)                                                                              5.0
# The Most Beautiful Day (2016)                                                                5.0
# Atrocious (2010)                                                                             5.0
# Extreme Prejudice (1987)                                                                     5.0
# Taken (2002)                                                                                 5.0
# Nous trois ou rien (2015)                                                                    5.0
# The Miseducation of Cameron Post (2018)                                                      5.0
# D.C.H. (Dil Chahta Hai) (2001)                                                               5.0
# Asterix & Obelix: God Save Britannia (Astérix et Obélix: Au service de Sa Majesté) (2012)    5.0
# Fading Gigolo (2013)                                                                         5.0
# Cutie Honey (2004)                                                                           5.0
# Custody (2018)                                                                               5.0
# Ashens and the Quest for the Gamechild (2013)                                                5.0
# Bully for Bugs (1953)                                                                        5.0
# Manhattan Night (2016)                                                                       5.0
# Tai Chi Master (Twin Warriors) (Tai ji: Zhang San Feng) (1993)                               5.0
# Jab We Met (2007)                                                                            5.0
# When You're Strange (2009)                                                                   5.0
# Through the Olive Trees (Zire darakhatan zeyton) (1994)                                      5.0
# O Pátio das Cantigas (1942)                                                                  5.0
# Everything Will Be All Right (1995)                                                          5.0
# American Dream (1990)                                                                        5.0
# Everything Is Copy (2015)                                                                    5.0
# Day of the Wacko (Dzien swira) (2002)                                                        5.0
# English Vinglish (2012)                                                                      5.0
# Kashtanka (1952)                                                                             5.0
# Bag of Hammers, A (2011)                                                                     5.0
# Badlapur (2015)                                                                              5.0
# Puss in Boots: The Three Diablos (2012)                                                      5.0
# Badhaai Ho (2018)                                                                            5.0
# Equinox Flower (Higanbana) (1958)                                                            5.0
# Kapoor and Sons (2016)                                                                       5.0
# This Filthy World (2006)                                                                     5.0
# Quiet Flows the Don (Tikhiy Don) (1957)                                                      5.0
# Kabir Singh (2019)                                                                           5.0
# Rabbit Fire (1951)                                                                           5.0
# Aziz Ansari: Live at Madison Square Garden (2015)                                            5.0
# Rabbits (2002)                                                                               5.0
# Obsession (1976)                                                                             5.0
# Juice (1992)                                                                                 5.0
# Wolf and Calf (1984)                                                                         5.0
# Aurora Borealis (2005)                                                                       5.0
# Ivans xtc. (2000)                                                                            5.0
# Arrival of a Train, The (1896)                                                               5.0
# Return to Halloweentown (2006)                                                               5.0
# Synthetic Pleasures (1995)                                                                   5.0
# Fitzwilly (1967)                                                                             5.0
# Five Corners (1987)                                                                          5.0
# Name: rating, dtype: float64
